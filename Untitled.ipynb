# %% [markdown]
# $$

# %%
import numpy as np

# %%
import statsmodels.api as sm

# %%
sm.OLS?

# %% [markdown]
# # OLS

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
a=np.linspace(0,10,20)
b=np.random.laplace(0,1,20)
plt.plot(a,b)

# %%
import seaborn as sns

# %%
sns.jointplot?
